# %%
## the reques library help us to hit the link and and take the json data and give us
import requests

# %%
# requests.get('request url').json()       ## command for the see the data in jupiter note book

response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=a451b38e2d62ad562a62559de80eaa57&language=en-US&page=1').json()

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/p1F51Lvj3sMopG948F5HsBbl43C.jpg',
#    'genre_ids': [28, 12, 14],
#    'id': 616037,
#    'original_language': 'en',
#    'original_title': 'Thor: Love and Thunder',
#    'overview': 'After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now inexplicably wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher’s vengeance and stop him before it’s too late.',
#    'popularity': 18650.943,
#    'poster_path': '/pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg',
#    'release_date': '2022-07-06',
#    'title': 'Thor: Love and Thunder',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 1506},
#   {'adult': False,
#    'backdrop_path': '/qTkJ6kbTeSjqfHCFCmWnfWZJOtm.jpg',
# ...

# %%
response['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/p1F51Lvj3sMopG948F5HsBbl43C.jpg',
#   'genre_ids': [28, 12, 14],
#   'id': 616037,
#   'original_language': 'en',
#   'original_title': 'Thor: Love and Thunder',
#   'overview': 'After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now inexplicably wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher’s vengeance and stop him before it’s too late.',
#   'popularity': 18650.943,
#   'poster_path': '/pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg',
#   'release_date': '2022-07-06',
#   'title': 'Thor: Love and Thunder',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 1506},
#  {'adult': False,
#   'backdrop_path': '/qTkJ6kbTeSjqfHCFCmWnfWZJOtm.jpg',
#   'genre_ids': [10751, 16, 12, 35, 14],
#   'id': 438148,
# ...

# %%
for i in response['results']:
    print(i['title'],i['vote_average'])
# Out:
# Thor: Love and Thunder 6.7
# Minions: The Rise of Gru 7.5
# Jurassic World Dominion 7.1
# Top Gun: Maverick 8.3
# The Black Phone 8
# Lightyear 7.3
# The Gray Man 7
# Doctor Strange in the Multiverse of Madness 7.5
# Dragon Knight 6.2
# The Exorcism of God 7.1
# The Princess 7.1
# Spider-Man: No Way Home 8.1
# Shut In 7.1
# The Ledge 6.2
# Last Seen Alive 6.6
# Sonic the Hedgehog 2 7.7
# Indemnity 6.3
# Vendetta 6.5
# Dog 7.4
# Hot Seat 6.8

# %%
import pandas as pd

# %%
## making empty list for stor the values by their corresonding values filling by the loop

popularity = []
vote_count = []
original_language = []
title = []
vote_average =[] 
overview =[] 
release_date = []

## useing the loop for appanding the value
for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
## making key {popularity,vote_count,orginal_language,title,vote avg,overview,release date}-- and thair apporprite value  
d = {'title':title, 'overview':overview,'original_language':original_language, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_count':vote_count ,'vote_average':vote_average}
    
    
df = pd.DataFrame(d)

# %%
### hear i am trying to hitting the 500 data pages and take that data and appending to my dataframe
final = pd.DataFrame()
for j in range(1,501):
    ## hear i use the {j} to changing the page value
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=a451b38e2d62ad562a62559de80eaa57&language=en-US&page={j}').json()    
    
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average =[] 
    overview =[] 
    release_date = []

    ## useing the loop for appanding the value
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])

    ## making key {popularity,vote_count,orginal_language,title,vote avg,overview,release date}-- and thair apporprite value  
    d = {'title':title, 'overview':overview,'original_language':original_language, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_count':vote_count ,'vote_average':vote_average}


    df = pd.DataFrame(d)
    
    final = final.append(df,ignore_index = True)

# %%
final.head()
# Out:
#                       title  \
# 0    Thor: Love and Thunder
# 1   Jurassic World Dominion
# 2  Minions: The Rise of Gru
# 3         Top Gun: Maverick
# 4           The Black Phone
#
#                                             overview original_language  \
# 0  After his retirement is interrupted by Gorr th...                en
# 1  Four years after Isla Nublar was destroyed, di...                en
# 2  A fanboy of a supervillain supergroup known as...                en
# 3  After more than thirty years of service as one...                en
# 4  Finney Shaw, a shy but clever 13-year-old boy,...                en
#
#   release_date  popularity  vote_count  vote_average
# 0   2022-07-06   18650.943        1506           6.7
# 1   2022-06-01    8765.449        2314           7.1
# 2   2022-06-29    8255.850         555           7.5
# 3   2022-05-24    7141.006        1762           8.3
# 4   2022-06-22    4767.764        1419           8.0

# %%
final.shape
# Out:
# (10000, 7)

# %%
final.to_csv('movies.csv')
